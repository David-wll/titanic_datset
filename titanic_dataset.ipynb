# %%
import pandas as pd
titanic_df = pd.read_csv("Titanic-Dataset.csv")

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df.isna().sum().sum()
# Out:
# np.int64(866)

# %%
mean_age = titanic_df['Age'].mean().round(0)

# %%
titanic_df['Age'].fillna(value = mean_age, inplace=True)
# Out:
# /tmp/ipython-input-749120926.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['Age'].fillna(value = mean_age, inplace=True)

# %%
titanic_df['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
titanic_df['Cabin'].ffill(inplace=True)
# Out:
# /tmp/ipython-input-4062759926.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['Cabin'].ffill(inplace=True)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df['Cabin'].bfill(inplace=True)
# Out:
# /tmp/ipython-input-3384516111.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['Cabin'].bfill(inplace=True)

# %%
titanic_df['Cabin'].isna().sum()
# Out:
# np.int64(0)

# %%
titanic_df['Embarked'].isna().sum()
# Out:
# np.int64(2)

# %%
titanic_df['Embarked'].ffill(inplace=True)
# Out:
# /tmp/ipython-input-1276939252.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['Embarked'].ffill(inplace=True)

# %%
titanic_df['Embarked'].isna().sum()
# Out:
# np.int64(0)

# %%
titanic_df.rename(columns={'SibSp': 'siblings/spouse', 'Parch':'Parent/Child'}, inplace=True)

# %%
titanic_df['Age'] = titanic_df['Age'].astype(int)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  \
# 0                              Braund, Mr. Owen Harris    male   22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2                               Heikkinen, Miss. Laina  female   26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4                             Allen, Mr. William Henry    male   35
# ..                                                 ...     ...  ...
# ...

# %%
titanic_df['Embarked'].replace(['S', 'C', 'Q'], ['Southhampton', 'Cherbourg', 'Queenstown'], inplace=True)
# Out:
# /tmp/ipython-input-3821802019.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['Embarked'].replace(['S', 'C', 'Q'], ['Southhampton', 'Cherbourg', 'Queenstown'], inplace=True)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  \
# 0                              Braund, Mr. Owen Harris    male   22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2                               Heikkinen, Miss. Laina  female   26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4                             Allen, Mr. William Henry    male   35
# ..                                                 ...     ...  ...
# ...

# %%
mapping_gender= {'male': 0, 'female': 1}

# %%
titanic_df['Sex'] = titanic_df['Sex'].map(mapping_gender)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  \
# 0                              Braund, Mr. Owen Harris    0   22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38
# 2                               Heikkinen, Miss. Laina    1   26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35
# 4                             Allen, Mr. William Henry    0   35
# ..                                                 ...  ...  ...
# 886                              Montvila, Rev. Juozas    0   27
# ...

# %%
titanic_df['Sex'].unique()
# Out:
# array([0, 1])

# %%
num = titanic_df['siblings/spouse'].value_counts()

num
# Out:
# siblings/spouse
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
num2 = titanic_df['Pclass'].value_counts()

num2
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic_df.groupby(['Sex', 'Survived'])['PassengerId'].count()
# Out:
# Sex  Survived
# 0    0           468
#      1           109
# 1    0            81
#      1           233
# Name: PassengerId, dtype: int64

# %%
titanic_df.groupby(['Pclass', 'Survived'])['PassengerId'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: PassengerId, dtype: int64

# %%
young_df = titanic_df[titanic_df['Age'] < 18]
young_df
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
first_class = titanic_df[titanic_df['Pclass'] == 1]
first_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Sex  Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35
# 6                              McCarthy, Mr. Timothy J    0   54
# 11                            Bonnell, Miss. Elizabeth    1   58
# 23                        Sloper, Mr. William Thompson    0   28
# ..                                                 ...  ...  ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)    1   47
# ...

# %%
len(first_class)
# Out:
# 216

# %%
adult_df = titanic_df[(titanic_df['Age'] >= 18) & (titanic_df['Age'] < 60)]

adult_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  \
# 0                              Braund, Mr. Owen Harris    0   22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38
# 2                               Heikkinen, Miss. Laina    1   26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35
# 4                             Allen, Mr. William Henry    0   35
# ..                                                 ...  ...  ...
# 886                              Montvila, Rev. Juozas    0   27
# ...

# %%
women_survive = titanic_df[(titanic_df['Sex'] == 1) & (titanic_df['Survived'] == 1)]

women_survive
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name  Sex  Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38
# 2                               Heikkinen, Miss. Laina    1   26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1   27
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    1   14
# ..                                                 ...  ...  ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)    1   28
# ...

# %%
dult_df =titanic_df.query('Age >= 18 and Age < 60')

dult_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  \
# 0                              Braund, Mr. Owen Harris    0   22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38
# 2                               Heikkinen, Miss. Laina    1   26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35
# 4                             Allen, Mr. William Henry    0   35
# ..                                                 ...  ...  ...
# 886                              Montvila, Rev. Juozas    0   27
# ...

# %%
dult_df['Age'].max()
# Out:
# 59

# %%
ter_df = titanic_df[(titanic_df['siblings/spouse'] >=1) & (titanic_df['Pclass'] == 3)]

ter_df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 13            14         0       3               Andersson, Mr. Anders Johan
# 16            17         0       3                      Rice, Master. Eugene
# ..           ...       ...     ...                                       ...
# 852          853         0       3                   Boulos, Miss. Nourelain
# 860          861         0       3                   Hansen, Mr. Claus Peter
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869          870         1       3           Johnson, Master. Harold Theodor
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic_df.isna().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age                0
# siblings/spouse    0
# Parent/Child       0
# Ticket             0
# Fare               0
# Cabin              0
# Embarked           0
# dtype: int64

# %%
#using label Encoder
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
titanic_df['Embarked'] = encoder.fit_transform(titanic_df['Embarked'])

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  \
# 0                              Braund, Mr. Owen Harris    0   22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38
# 2                               Heikkinen, Miss. Laina    1   26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35
# 4                             Allen, Mr. William Henry    0   35
# ..                                                 ...  ...  ...
# 886                              Montvila, Rev. Juozas    0   27
# ...

# %%
titanic_df['Age_Group'] = pd.cut(titanic_df['Age'], bins=3, labels=['Young', 'Adult', 'Old'])

# %%
sales_data = { "product": ['iPhone12', 'iPhone12 pro', 'iPhone13', 'Samsung Gallary Note 20', 'Techno Pop 16'],
              "Unit price": [450000, 550000, 600000, 400000, 120000],
               'Quantity': [100, 200, 300, 45, 300],
               "Cost Price":[500000, 600000, 650000, 500000, 150000]




}

# %%
pd.DataFrame(sales_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3842008106.py in <cell line: 0>()
# ----> 1 pd.DataFrame(sales_data)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Assignment
